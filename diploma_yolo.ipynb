# %% [markdown]
# **Connect google drive**

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Sun Apr 25 11:34:37 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  bambi10.zip	     DiplomatervSablon_v3.1.doc   signature.png
#  bambi9.zip	     intelligens		 'Untitled folder'
#  BME		     Intelligens.gdoc		  yolov3
#  Calculatorgep.zip   jegyzokonyv7.docx		  YOLOv3
#  calculator.txt      Linbohocok.zip		  yolov4
#  Classroom	    'My Drive'
# 'Colab Notebooks'    rgb.c

# %% [markdown]
# **1) Clone the Darknet**

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14978, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 14978 (delta 9), reused 22 (delta 7), pack-reused 14949
# Receiving objects: 100% (14978/14978), 13.40 MiB | 18.37 MiB/s, done.
# Resolving deltas: 100% (10172/10172), done.

# %% [markdown]
# **2) Compile Darknet using Nvidia GPU**

# %%
#YOLO3
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make

# %%
#YOLO4
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# !make

# %% [markdown]
# **3) Configure Darknet network for training YOLO V3**

# %%
#YOLO3
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
#YOLO4
# !cp cfg/yolov4-custom.cfg cfg/yolov4_training.cfg

# %%
#YOLO3
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=32/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov3_training.cfg
# !sed -i 's/steps=400000,450000/steps=3200,3600/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=21@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=21@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=21@' cfg/yolov3_training.cfg

# %%
#YOLO4
# !sed -i 's/max_batches = 500500/max_batches = 4000/' cfg/yolov4_training.cfg
# !sed -i 's/steps=400000,450000/steps=3200,3600/' cfg/yolov4_training.cfg
# !sed -i '970 s@classes=80@classes=2@' cfg/yolov4_training.cfg
# !sed -i '1058 s@classes=80@classes=2@' cfg/yolov4_training.cfg
# !sed -i '1146 s@classes=80@classes=2@' cfg/yolov4_training.cfg
# !sed -i '963 s@filters=255@filters=21@' cfg/yolov4_training.cfg
# !sed -i '1051 s@filters=255@filters=21@' cfg/yolov4_training.cfg
# !sed -i '1139 s@filters=255@filters=21@' cfg/yolov4_training.cfg

# %%
# !echo -e 'szakadas\nfurat' > data/obj.names
# !echo -e 'classes= 2\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolov4' > data/obj.data
# !mkdir data/obj

# %%
#YOLO3
# !wget https://pjreddie.com/media/files/darknet53.conv.74

# %%
#YOLO4
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %% [markdown]
# **4) Extract Images**
#
# The images need to be inside a zip archive called "images.zip" and they need to be inside the folder "yolov3" on Google Drive

# %%
# !unzip /mydrive/yolov4/train_images.zip -d data/obj
# Out:
# Archive:  /mydrive/yolov4/train_images.zip
#   inflating: data/obj/model0.png
#   inflating: data/obj/model0.txt
#   inflating: data/obj/model1.png
#   inflating: data/obj/model1.txt
#   inflating: data/obj/model10.png
#   inflating: data/obj/model10.txt
#   inflating: data/obj/model11.png
#   inflating: data/obj/model11.txt
#   inflating: data/obj/model12.png
#   inflating: data/obj/model12.txt
#   inflating: data/obj/model13.png
#   inflating: data/obj/model13.txt
#   inflating: data/obj/model14.png
#   inflating: data/obj/model14.txt
#   inflating: data/obj/model15.png
#   inflating: data/obj/model15.txt
#   inflating: data/obj/model16.png
#   inflating: data/obj/model16.txt
#   inflating: data/obj/model17.png
#   inflating: data/obj/model17.txt
#   inflating: data/obj/model18.png
#  extracting: data/obj/model18.txt
#   inflating: data/obj/model19.png
#   inflating: data/obj/model19.txt
#   inflating: data/obj/model2.png
#   inflating: data/obj/model2.txt
# ...

# %%
import glob
images_list = glob.glob("data/obj/*.png")
print(images_list)
# Out:
# ['data/obj/model53.png', 'data/obj/model92.png', 'data/obj/model17.png', 'data/obj/model20.png', 'data/obj/model18.png', 'data/obj/model76.png', 'data/obj/model75.png', 'data/obj/model96.png', 'data/obj/model36.png', 'data/obj/model54.png', 'data/obj/model59.png', 'data/obj/model97.png', 'data/obj/model38.png', 'data/obj/model98.png', 'data/obj/model28.png', 'data/obj/model11.png', 'data/obj/model44.png', 'data/obj/model8.png', 'data/obj/model73.png', 'data/obj/model0.png', 'data/obj/model13.png', 'data/obj/model63.png', 'data/obj/model35.png', 'data/obj/model55.png', 'data/obj/model49.png', 'data/obj/model46.png', 'data/obj/model45.png', 'data/obj/model2.png', 'data/obj/model88.png', 'data/obj/model57.png', 'data/obj/model16.png', 'data/obj/model14.png', 'data/obj/model50.png', 'data/obj/model42.png', 'data/obj/model72.png', 'data/obj/model43.png', 'data/obj/model94.png', 'data/obj/model51.png', 'data/obj/model68.png', 'data/obj/model61.png', 'data/obj/model83.png', 'data/obj/model8
# ...

# %%
#Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %%
# !mkdir data/test

# %%
# !unzip /mydrive/yolov4/test_images.zip -d data/test
# Out:
# Archive:  /mydrive/yolov4/test_images.zip
#  extracting: data/test/classes.txt
#   inflating: data/test/model0.png
#   inflating: data/test/model0.txt
#   inflating: data/test/model1.png
#   inflating: data/test/model1.txt
#   inflating: data/test/model10.png
#  extracting: data/test/model10.txt
#   inflating: data/test/model11.png
#   inflating: data/test/model11.txt
#   inflating: data/test/model12.png
#   inflating: data/test/model12.txt
#   inflating: data/test/model13.png
#   inflating: data/test/model13.txt
#   inflating: data/test/model14.png
#   inflating: data/test/model14.txt
#   inflating: data/test/model15.png
#   inflating: data/test/model15.txt
#   inflating: data/test/model16.png
#  extracting: data/test/model16.txt
#   inflating: data/test/model17.png
#   inflating: data/test/model17.txt
#   inflating: data/test/model18.png
#   inflating: data/test/model18.txt
#   inflating: data/test/model19.png
#   inflating: data/test/model19.txt
# ...

# %%
#Create test.txt file
images_list = glob.glob("data/test/*.png")
print(images_list)
file = open("data/test.txt", "w") 
file.write("\n".join(images_list)) 
file.close()
# Out:
# ['data/test/model17.png', 'data/test/model20.png', 'data/test/model18.png', 'data/test/model36.png', 'data/test/model38.png', 'data/test/model28.png', 'data/test/model11.png', 'data/test/model44.png', 'data/test/model8.png', 'data/test/model0.png', 'data/test/model13.png', 'data/test/model35.png', 'data/test/model49.png', 'data/test/model46.png', 'data/test/model45.png', 'data/test/model2.png', 'data/test/model16.png', 'data/test/model14.png', 'data/test/model42.png', 'data/test/model43.png', 'data/test/model40.png', 'data/test/model10.png', 'data/test/model39.png', 'data/test/model34.png', 'data/test/model22.png', 'data/test/model19.png', 'data/test/model15.png', 'data/test/model12.png', 'data/test/model30.png', 'data/test/model6.png', 'data/test/model27.png', 'data/test/model5.png', 'data/test/model26.png', 'data/test/model9.png', 'data/test/model33.png', 'data/test/model25.png', 'data/test/model31.png', 'data/test/model37.png', 'data/test/model47.png', 'data/test/model7.png', 'dat
# ...

# %% [markdown]
# **6) Start the training**

# %% [markdown]
# cntrl+shift+i
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show -map
# Out:
# A streamkimeneten csak az utolsó 5000 sor látható.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.756137), count: 8, class_loss = 0.288664, iou_loss = 0.630114, total_loss = 0.918778
#  total_bbox = 205992, rewritten_bbox = 0.003398 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.855613), count: 2, class_loss = 0.000004, iou_loss = 0.051273, total_loss = 0.051277
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.853010), count: 1, class_loss = 0.002165, iou_loss = 0.018513, total_loss = 0.020678
#  total_bbox = 205995, rewritten_bbox = 0.003398 %
# ...

# %%
# !./darknet detector train data/obj.data cfg/yolov4_training.cfg yolov4.conv.137 -dont_show -map

# %%
download('chart.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-10f1d7cc4bfd> in <module>()
# ----> 1 download('chart.png')
#
# NameError: name 'download' is not defined

# %% [markdown]
# 7) Test

# %%
# need to set our custom cfg to test mode 
# %cd cfg
# !sed -i 's/batch=64/batch=64/' yolov3_training.cfg
# !sed -i 's/subdivisions=16/subdivisions=16/' yolov3_training.cfg
# %cd ..

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
# run your custom detector with this command (upload an image to your google drive to test, thresh flag sets accuracy that detection must be in order to show it)
# !./darknet detector test data/obj.data cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov3/yolov3_training_last.weights /content/gdrive/MyDrive/yolov3/test_images/model7.png -thresh 0.3
imShow("predictions.jpg")

# %%
# !./darknet detector test data/obj.data cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov4/yolov3_training_last.weights -dont_show -ext_output < data/test.txt > result.txt
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
# ...

# %%
# !./darknet detector recall data/obj.data cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov4/yolov3_training_last.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 32, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
# !./darknet detector valid  data/obj.data cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov4/yolov3_training_last.weights

# %%
# !./darknet detector map data/obj.data cfg/yolov3_training.cfg /content/gdrive/MyDrive/yolov4/yolov3_training_last.weights
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 32, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
# ...

# %%
import cv2
import numpy as np
import glob
import random
from google.colab.patches import cv2_imshow


# Load Yolo
net = cv2.dnn.readNet("/content/gdrive/MyDrive/yolov3/yolov3_training_last.weights", "/content/gdrive/MyDrive/yolov3/yolov3_testing.cfg")

# Name custom object
classes = ["szakadas","furat"]

layer_names = net.getLayerNames()
output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
colors = np.random.uniform(0, 255, size=(len(classes), 3))

# Images path
images_path = glob.glob(r"/content/gdrive/MyDrive/yolov3/test_images/*.png")



layer_names = net.getLayerNames()
output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
colors = np.random.uniform(0, 255, size=(len(classes), 3))

# Insert here the path of your images
random.shuffle(images_path)

for img_path in images_path:
    # Loading image
    img = cv2.imread(img_path)
    img = cv2.resize(img, None, fx=0.4, fy=0.4)
    height, width, channels = img.shape

    # Detecting objects
    blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), (0, 0, 0), True, crop=False)

    net.setInput(blob)
    outs = net.forward(output_layers)

    # Showing informations on the screen
    class_ids = []
    confidences = []
    boxes = []
    for out in outs:
        for detection in out:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]
            if confidence > 0.8:
                # Object detected
                print(class_id)
                center_x = int(detection[0] * width)
                center_y = int(detection[1] * height)
                w = int(detection[2] * width)
                h = int(detection[3] * height)

                # Rectangle coordinates
                x = int(center_x - w / 2)
                y = int(center_y - h / 2)

                boxes.append([x, y, w, h])
                confidences.append(float(confidence))
                class_ids.append(class_id)

    indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)
    print(indexes)
    font = cv2.FONT_HERSHEY_PLAIN
    for i in range(len(boxes)):
        if i in indexes:
            x, y, w, h = boxes[i]
            label = str(classes[class_ids[i]])
            color = colors[class_ids[i]]
            cv2.rectangle(img, (x, y), (x + w, y + h), color, 2)
            cv2.putText(img, label, (x, y + 30), font, 3, color, 2)


    cv2_imshow(img)

# %%
# run your custom detector with this command (upload an image to your google drive to test, thresh flag sets accuracy that detection must be in order to show it)
# !./darknet detector test data/obj.data cfg/yolov3_custom.cfg /content/gdrive/MyDrive/yolov3/yolov3_training_last.weights /content/gdrive/MyDrive/yolov3/test_images/model1.png -thresh 0.3
imShow('predictions.jpg')
